# %% [markdown]
# # **Data Preprocessing**

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# # **Imported all the libraries needed for this project**
#
# *   Imported pandas for reading the diffierent file formats like csv , text, and etc.
#
#
# *    Imported numpy for data caculation.
#
#
# *   Imported matplotlib and seaborn for data visualization.
#
#
#
#
# *   Imported tain_test_split from sklearn for splitting the data into train and test sets.
#
# *   Imported k-Neightbor classifier from sklearn as a machine learning model.
#
#
# *   Imported classification report and accuracy score from sklearn for classification and accuracy

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # **Reading different file format using pandas libraries. and create columns as names for further different uses.**

# %%
df = pd.read_csv("/content/drive/MyDrive/Datasets/cybersecurity_attacks.csv")
df.head(10)

# %% [markdown]
# # **This inbild fuction is used to display shape of the rows and columns in matrix. Here is shows 2-D matrix.**

# %%
df.shape

# %% [markdown]
# # **This inbuild fuction is used to display each column non null and null count and data type. Here every column has 4000 non null count**

# %%
df.info()

# %% [markdown]
# # **This inbild fuction is used to display each column mean , medium , total count , standard deviation , min and max value. This fuction only workd on numerical values.**

# %%
df.describe()

# %% [markdown]
# # **This inbuild function is used display the null value present in the datasets**

# %%
df.isnull().sum()

# %% [markdown]
# # **This inbuild function is used to drop specific unwanted column from the dataset.**

# %%
df_1 = df.drop(['Timestamp'] , axis = 1)

# %% [markdown]
# # **This inbuild function is used to drop all the null or missing value present in the dataset.**

# %%
df_2 = df_1.dropna()
df_2.head()

# %% [markdown]
# # **This inbuild function is used to save the preproced data in a specified location and file. Here index keyword avaoid any extra unwanted coloumn automatically created.**

# %%
df_2.to_csv('/content/drive/MyDrive/Datasets/cybersecurity_attacks_preprocessed_data' , index = False)

# %% [markdown]
# # **Reading different file format using pandas libraries. and create columns as names for further different uses. Here I am reading the new preprocessed created file**

# %%
df_3 = pd.read_csv('/content/drive/MyDrive/Datasets/cybersecurity_attacks_preprocessed_data')
df_3.head()

# %% [markdown]
# # **This inbild fuction is used to display shape of the rows and columns in matrix. Here is shows 2-D matrix. Here after preprocessing the size of the matrix has gone low**

# %%
df_3.shape

# %% [markdown]
# # **This inbild fuction is used to display each column mean , medium , total count , standard deviation , min and max value. This fuction only workd on numerical values. Here mean , medium , total count , standard deviation , min and max value has been change afer preprocessing**

# %%
df_3.describe()

# %% [markdown]
# # **Conclusion**
#
#
# *   After preprocessing mean , medium , standard deviation , min and max value has increased even the total count has been decreased.
# *   The effication of the dataset for better analysis and quality has been increased.
# *   Preprocessed data will show better representation in graphical form.
# *   Preprocessed data will have better machine learning model performance.
