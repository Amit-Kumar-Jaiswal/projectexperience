# %%
import torch
import numpy as np

# %%
list_ = np.random.rand(1 , 10)
list_.reshape(-1 , 1)
# Out:
# array([[0.95411123],
#        [0.97000107],
#        [0.6330431 ],
#        [0.28859384],
#        [0.45751825],
#        [0.31508065],
#        [0.6638715 ],
#        [0.7490194 ],
#        [0.63782064],
#        [0.74894809]])

# %%
pyt = torch.randn(1 , 10)
pyt.reshape(-1 , 1)
# Out:
# tensor([[ 3.0878],
#         [ 0.4412],
#         [-0.7375],
#         [-1.0671],
#         [-0.7067],
#         [ 0.4606],
#         [ 0.8198],
#         [ 1.0821],
#         [-0.4832],
#         [-1.7785]])
