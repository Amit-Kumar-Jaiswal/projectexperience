# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings
# %matplotlib inline

# %%
df = pd.read_csv('/content/drive/MyDrive/Datasets/randompct.csv')
df.head()
# Out:
#    No.  Time        Source Destination Protocol  source port  \
# 0    1   0.0  208.21.2.184   10.1.1.99      UDP      49391.0
# 1    2   1.0  208.21.2.184   10.1.1.99      UDP      26667.0
# 2    3   2.0  208.21.2.184   10.1.1.99      UDP       1710.0
# 3    4   3.0  208.21.2.184   10.1.1.99      UDP      53887.0
# 4    5   4.0  208.21.2.184   10.1.1.99      UDP      25117.0
#
#    Destination port  Length  Host  \
# 0           22166.0     993   NaN
# 1           59951.0    1745   NaN
# 2           37558.0     345   NaN
# 3           46287.0    1209   NaN
# 4           48370.0    1042   NaN
#
#    Time since previous frame in this TCP stream  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#                                                 Info
# ...

# %%
df['Time since previous frame in this TCP stream']
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#         ..
# 4995   NaN
# 4996   NaN
# 4997   NaN
# 4998   NaN
# 4999   NaN
# Name: Time since previous frame in this TCP stream, Length: 5000, dtype: float64

# %%
df['Host']
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#         ..
# 4995   NaN
# 4996   NaN
# 4997   NaN
# 4998   NaN
# 4999   NaN
# Name: Host, Length: 5000, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 11 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   No.                                           5000 non-null   int64
#  1   Time                                          5000 non-null   float64
#  2   Source                                        5000 non-null   object
#  3   Destination                                   5000 non-null   object
#  4   Protocol                                      5000 non-null   object
#  5   source port                                   4980 non-null   float64
#  6   Destination port                              4980 non-null   float64
#  7   Length                                        5000 non-null   int64
#  8   Host                                          0 non-null      float64
# ...

# %%
df.isna().sum()
# Out:
# No.                                                0
# Time                                               0
# Source                                             0
# Destination                                        0
# Protocol                                           0
# source port                                       20
# Destination port                                  20
# Length                                             0
# Host                                            5000
# Time since previous frame in this TCP stream    5000
# Info                                              11
# dtype: int64

# %%
df.describe()
# Out:
#                No.         Time   source port  Destination port       Length  \
# count  5000.000000  5000.000000   4980.000000       4980.000000  5000.000000
# mean   2500.500000  2499.500000  32312.321285      30811.434940  1019.737000
# std    1443.520003  1443.520003  18931.461384      19342.715321   567.408836
# min       1.000000     0.000000      3.000000          1.000000    34.000000
# 25%    1250.750000  1249.750000  15276.500000      13348.750000   530.750000
# 50%    2500.500000  2499.500000  32316.500000      29440.000000  1032.000000
# 75%    3750.250000  3749.250000  48750.000000      47536.750000  1508.250000
# max    5000.000000  4999.000000  65517.000000      65500.000000  2000.000000
#
#        Host  Time since previous frame in this TCP stream
# count   0.0                                           0.0
# mean    NaN                                           NaN
# std     NaN                                           NaN
# ...

# %%
df.drop(['Host' , 'Time since previous frame in this TCP stream' , 'No.'] , axis = 1 , inplace = True)

# %%
df.head(50)
# Out:
#     Time        Source Destination Protocol  source port  Destination port  \
# 0    0.0  208.21.2.184   10.1.1.99      UDP      49391.0           22166.0
# 1    1.0  208.21.2.184   10.1.1.99      UDP      26667.0           59951.0
# 2    2.0  208.21.2.184   10.1.1.99      UDP       1710.0           37558.0
# 3    3.0  208.21.2.184   10.1.1.99      UDP      53887.0           46287.0
# 4    4.0  208.21.2.184   10.1.1.99      UDP      25117.0           48370.0
# 5    5.0  208.21.2.184   10.1.1.99      UDP       4317.0           62130.0
# 6    6.0  208.21.2.184   10.1.1.99      UDP      48583.0           27650.0
# 7    7.0  208.21.2.184   10.1.1.99      UDP      50150.0           50788.0
# 8    8.0  208.21.2.184   10.1.1.99      UDP      28727.0           49690.0
# 9    9.0  208.21.2.184   10.1.1.99      UDP      54153.0           23158.0
# 10  10.0  208.21.2.184   10.1.1.99      UDP      41699.0           56309.0
# ...

# %%
df.isna().sum()
# Out:
# Time                 0
# Source               0
# Destination          0
# Protocol             0
# source port         20
# Destination port    20
# Length               0
# Info                11
# dtype: int64

# %%
df.dropna(inplace = True)

# %%
df1 = df['Info'].str.split(expand = True)
df1.to_csv('/content/drive/MyDrive/Datasets/infocolumnsplit' , index = False)

# %%
df2 = pd.read_csv('/content/drive/MyDrive/Datasets/infocolumnsplit')
df2.head()
# Out:
# pandas.core.frame.DataFrame

# %%
df2.info()
